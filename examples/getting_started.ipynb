# %% [markdown]
# # From a small warehouse instance to pipeline candidates
#
# This example uses a deliberately tiny, synthetic instance so that every value can be inspected. It does not depend on a benchmark file or a data loader. We create the domain objects, let the algorithm cards filter the feasible candidates, and compare two concrete pick orders in a plot.
#
# The point is the hand-off between **warehouse facts** and **pipeline synthesis**: the same algorithm catalogue can produce a different candidate set when the layout, storage, or order features change.

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

from ware_ops_algos.algorithms import GreedyItemAssignment
from ware_ops_algos.algorithms.algorithm_cards import load_packaged_algo_cards
from ware_ops_algos.domain_algo_mapper.domain_algo_mapper import DomainAlgorithmMapper
from ware_ops_algos.domain_models import (
    Article, ArticleType, Articles, BaseWarehouseDomain,
    LayoutData, LayoutNetwork, LayoutParameters, LayoutType,
    Location, Order, OrderPosition, OrderType, OrdersDomain,
    Resource, Resources, ResourceType, StorageLocations, StorageType,
    WarehouseInfo, WarehouseInfoType,
)
from ware_ops_algos.taxonomy.taxonomy import TAXONOMY

# %% [markdown]
# ## 1. Describe the instance
#
# There are three articles, four storage locations, and one order. The order deliberately visits the farthest article first, which makes the routing comparison visible.

# %%
depot = (0, 0)
locations = [
    Location(x=1, y=2, article_id=101, amount=4),
    Location(x=1, y=6, article_id=101, amount=3),
    Location(x=2, y=4, article_id=102, amount=2),
    Location(x=2, y=7, article_id=103, amount=5),
]

storage = StorageLocations(StorageType.DEDICATED, locations=locations)
storage.build_article_location_mapping()

orders = OrdersDomain(
    OrderType.STANDARD,
    orders=[Order(
        order_id=1,
        order_positions=[
            OrderPosition(order_number=1, article_id=103, amount=1),
            OrderPosition(order_number=1, article_id=101, amount=2),
            OrderPosition(order_number=1, article_id=102, amount=1),
        ],
    )],
)

articles = Articles(
    ArticleType.STANDARD,
    articles=[
        Article(article_id=101, weight=1.2, volume=0.5),
        Article(article_id=102, weight=0.8, volume=0.3),
        Article(article_id=103, weight=2.0, volume=0.7),
    ],
)
resources = Resources(
    ResourceType.HUMAN,
    resources=[Resource(id=1, speed=1.0, time_per_pick=0.5)],
)

# %%
def manhattan(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

nodes = [depot, (1, 2), (1, 6), (2, 4), (2, 7)]
graph = nx.Graph()
graph.add_nodes_from(nodes)
distance_matrix = pd.DataFrame(
    [[manhattan(a, b) for b in nodes] for a in nodes],
    index=nodes,
    columns=nodes,
)

layout = LayoutData(
    tpe=LayoutType.CONVENTIONAL,
    graph_data=LayoutParameters(
        n_aisles=2, n_pick_locations=7, n_blocks=1,
        dist_top_to_pick_location=1, dist_bottom_to_pick_location=1,
        dist_pick_locations=1, dist_aisle=1, dist_start=0,
        start_location=depot, end_location=depot, dist_end=0,
    ),
    layout_network=LayoutNetwork(
        graph=graph, distance_matrix=distance_matrix,
        start_node=depot, end_node=depot, closest_node_to_start=(1, 2),
        min_aisle_position=1, max_aisle_position=7, node_list=nodes,
    ),
)

warehouse = BaseWarehouseDomain(
    problem_class="OBRP", objective="distance", layout=layout,
    articles=articles, orders=orders, resources=resources, storage=storage,
    warehouse_info=WarehouseInfo(WarehouseInfoType.OFFLINE),
)

print(f"{len(orders.orders)} order, {len(orders.orders[0].order_positions)} order lines, "
      f"{len(storage.locations)} storage locations")
print("Order demand:", [(p.article_id, p.amount) for p in orders.orders[0].order_positions])

# %% [markdown]
# ## 2. Filter the algorithm catalogue
#
# The mapper uses the instance's problem class and domain features. This is the decision point that a loader-backed runner would normally reach after parsing an instance; here it is explicit and small enough to inspect.

# %%
cards = load_packaged_algo_cards()
mapper = DomainAlgorithmMapper(TAXONOMY)
applicable = mapper.filter(cards, warehouse)

print(f"Applicable algorithms: {len(applicable)} of {len(cards)}")
print([card.algo_name for card in applicable])
print("Layout features used by the mapper:")
print(warehouse.layout.get_features())

# %% [markdown]
# ## 3. Make the values visible
#
# Greedy item assignment resolves article demand to physical pick nodes. The plot compares the order as entered with the same three nodes sorted by their distance from the depot. The sorted order is only an illustration of how a routing choice changes the objective; it is not presented as a replacement for the routing algorithms.

# %%
assignment = GreedyItemAssignment(storage).solve(orders.orders)
pick_nodes = [position.pick_node for position in assignment.resolved_orders[0].pick_positions]
input_route = [depot, *pick_nodes, depot]
sorted_route = [depot, *sorted(pick_nodes, key=lambda node: manhattan(depot, node)), depot]

def route_distance(route):
    return sum(manhattan(a, b) for a, b in zip(route, route[1:]))

input_distance = route_distance(input_route)
sorted_distance = route_distance(sorted_route)
print(f"Assigned pick nodes: {pick_nodes}")
print(f"Input order distance: {input_distance}")
print(f"Distance-sorted illustration: {sorted_distance}")
print(f"Difference: {input_distance - sorted_distance}")

fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharex=True, sharey=True)
for axis, route, title, distance in [
    (axes[0], input_route, "Order as entered", input_distance),
    (axes[1], sorted_route, "Distance-sorted illustration", sorted_distance),
]:
    x, y = zip(*route)
    axis.plot(x, y, "-o", color="#007c91")
    axis.scatter(*depot, color="#d1495b", s=90, label="depot", zorder=3)
    for step, node in enumerate(route[1:-1], start=1):
        axis.annotate(str(step), node, xytext=(5, 5), textcoords="offset points")
    axis.set_title(f"{title}\n{distance} distance units")
    axis.set_xlabel("aisle")
    axis.grid(alpha=0.25)
axes[0].set_ylabel("position")
fig.suptitle("One order, two visit sequences")
fig.tight_layout()
plt.show()

# %% [markdown]
# ### What to take away
#
# * Domain objects preserve the facts that matter for compatibility: two aisles, one block, dedicated storage, and one offline picker.
# * The mapper turns those facts into a measurable candidate set (the printed `Applicable algorithms` count).
# * Assignment produces physical pick nodes, after which routing can compare concrete distances.
#
# To try a different context, change one fact—such as `n_blocks=2` or `StorageType.SCATTERED`—and rerun the catalogue-filtering cell. The candidate list should change without changing the algorithm catalogue.
