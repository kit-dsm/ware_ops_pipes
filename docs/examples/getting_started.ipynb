# %%
from pathlib import Path
from typing import Tuple

PROJECT_ROOT = Path().resolve().parent.parent
DATA_DIR = PROJECT_ROOT / "data"

instances_base = DATA_DIR / "instances"
cache_base = DATA_DIR / "instances" / "caches"

# %% [markdown]
# # Run 3D4L on a Single Instance

# %% [markdown]
# This example shows how to define a custom pipeline runner to execute automated pipeline synthesis for a single instance. We utilize the FoodmartLoader class from ware_ops_algos to translate the instance file into a domain object compatible with 3D4L.

# %%
from ware_ops_algos.domain_models import BaseWarehouseDomain
from ware_ops_algos.data_loaders import FoodmartLoader
from ware_ops_pipes.utils.experiment_utils import PipelineRunner, RankingEvaluatorDistance


class SimpleRunner(PipelineRunner):
    def __init__(self, instance_set_name: str, 
                 instances_dir: Path, 
                 cache_dir: Path, 
                 project_root: Path):
        super().__init__(instance_set_name, 
                         instances_dir, 
                         cache_dir, 
                         project_root)
        
        self.loader = FoodmartLoader(str(instances_dir), 
                                     str(cache_dir))
        self.ranker = RankingEvaluatorDistance
        
    def discover_instances(self) -> list[Tuple[str, list[Path]]]:
        pass
    
    def load_domain(self, instance_name: str, 
                    file_paths: list[Path]) -> BaseWarehouseDomain:
        return self.loader.load(file_paths[0].name, use_cache=True)

runner = SimpleRunner("FoodmartData", instances_base / "FoodmartData",
                        cache_base / "FoodmartData", PROJECT_ROOT)

runner.run_instance(instance_name="instances_d5_ord5_MAL.txt", file_paths=[Path("data/instances/FoodmartData/instances_d5_ord5_MAL.txt")])
# Out:
# Loaded 38 model cards
#
# ================================================================================
# Processing: instances_d5_ord5_MAL.txt
# ================================================================================
#
# Problem type filtering for 'OBRP':
#   Accepted types: {'OBRP', 'order_selection', 'batching', 'item_assignment', 'routing'}
#   Result: 32/38 algorithms match
#
#   Checking: ClarkAndWrightNN
#     ✓ Algorithm is feasible
#
#   Checking: ClarkAndWrightRR
#     ✗ layout: constraint violated - n_blocks=2 does not satisfy {'equals': 1}
#
#   Checking: ClarkAndWrightSShape
#     ✓ Algorithm is feasible
#
#   Checking: ClosestDepotMaxSharedArticlesSeedBatching
#     ✓ Algorithm is feasible
#
#   Checking: ClosestDepotMinDistanceSeedBatching
#     ✓ Algorithm is feasible
#
#   Checking: CombinedBatchingRoutingAssigning
#     ✓ Algorithm is feasible
#
#   Checking: DueDate
#     ✗ orders: constraint violated - due_date=False does not satisfy {'equals': True}
#
#   Checking: FiFo
#     ✗ orders: constraint violated - order_date=False does not satisfy {'equals': True}
#
#   Checking: GreedyIA
#     ✓ Algorithm is feasible
#
#   Checking: NNItemAssignment
#     ✗ storage: type 'dedicated' not in required types ['scattered']
#
#   Checking: LargestGap
#     ✓ Algorithm is feasible
#
#   Checking: LSBatchingNNDueDate
#     ✗ orders: constraint violated - due_date=False does not satisfy {'equals': True}
#
#   Checking: LSBatchingNNFiFo
#     ✗ orders: constraint violated - order_date=False does not satisfy {'equals': True}
#
#   Checking: LSBatchingNNRand
#     ✓ Algorithm is feasible
#
#   Checking: LSBatchingRR
#     ✗ layout: constraint violated - n_blocks=2 does not satisfy {'equals': 1}
#
#   Checking: Midpoint
#     ✓ Algorithm is feasible
#
#   Checking: NearestNeighbourhood
#     ✓ Algorithm is feasible
#
#   Checking: OrderNrFiFo
#     ✗ orders: missing required features ['order_number']
#
#   Checking: DummyOS
#     ✓ Algorithm is feasible
#
#   Checking: GreedyOS
#     ✗ warehouse_info: type 'offline' not in required types ['online']
#
#   Checking: MinSharedAislesOS
#     ✗ warehouse_info: type 'offline' not in required types ['online']
#
#   Checking: MinMaxAislesOS
#     ✗ resources: type 'human' not in required types ['mixed']
#
#   Checking: MinMaxArticlesOS
#     ✗ resources: type 'human' not in required types ['mixed']
#
#   Checking: PLRouting
#     ✓ Algorithm is feasible
#
#   Checking: Random
#     ✓ Algorithm is feasible
#
#   Checking: RandomMinDistanceSeedBatching
#     ✓ Algorithm is feasible
#
#   Checking: RandomSimArticlesSeedBatching
#     ✗ orders: missing required features ['id']
#
#   Checking: Return
#     ✓ Algorithm is feasible
#
#   Checking: RatliffRosenthal
#     ✗ layout: constraint violated - n_blocks=2 does not satisfy {'equals': 1}
#
#   Checking: SPRPNF
#     ✗ layout: missing required features ['state_graph']
#
#   Checking: SShape
#     ✓ Algorithm is feasible
#
#   Checking: ExactSolving
#     ✓ Algorithm is feasible
#
# Requirement filtering: 17/32 algorithms feasible
#
# Final result: 17/38 algorithms are feasible
# ✓ 17/38 algorithms applicable
# ✅ ClarkAndWrightNN
# ✅ ClarkAndWrightSShape
# ✅ ClosestDepotMaxSharedArticlesSeedBatching
# ✅ ClosestDepotMinDistanceSeedBatching
# ⚠ Unknown model: CombinedBatchingRoutingAssigning, skipping...
# ✅ GreedyIA
# ✅ LargestGap
# ✅ LSBatchingNNRand
# ✅ Midpoint
# ✅ NearestNeighbourhood
# ✅ DummyOS
# ✅ PLRouting
# ✅ Random
# ⚠ Unknown model: RandomMinDistanceSeedBatching, skipping...
# ✅ Return
# ✅ SShape
# ⚠ Unknown model: ExactSolving, skipping...
# C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\.venv\Lib\site-packages\luigi\parameter.py:296: UserWarning: Parameter "instance_set_name" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\.venv\Lib\site-packages\luigi\parameter.py:296: UserWarning: Parameter "instance_name" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\.venv\Lib\site-packages\luigi\parameter.py:296: UserWarning: Parameter "instance_path" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\.venv\Lib\site-packages\luigi\parameter.py:296: UserWarning: Parameter "domain_path" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# Collecting repository...
# Build repository...
# Building tree grammar and inhabiting pipelines...
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_044b0b57b8   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_b77516d9d1   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_49ea68daa9   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_57149dcb38   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_75ef682193   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_006a523e91   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_0f583a89a7   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_017dbd2eee   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_64f04937b6   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_2d642ffb8e   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_9d02b6da68   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_cd446e708e   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_9f4afdb7ff   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_937117920e   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_c007d92264   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_08d14f6bd6   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_17776b3738   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_609f55067a   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_62188dd01f   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_23447219e7   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_1591452464   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_e9bf960bc7   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_ae5c5fc26a   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_5c2ec5417c   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_f4c36c9bbe   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_af121e28f4   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_e8a017f9d4   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_3b0c14720d   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_0fd8485f88   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_0c4ba1a348   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_ee16996b43   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_23b5aac176   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_f7963d6441   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_c394e48f1b   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_005a39dc8f   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_96e6963a87   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_d4ff750664   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_65374d1ee6   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_6ecede1a1e   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_733e984cbe   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_afef3e2157   has status   DONE
# INFO: Informed scheduler that task   ResultAggregationDistance______type______cl_88fa9b4627   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# INFO: Worker Worker(salt=4346423591, workers=1, host=imi-nb102, username=zm0714, pid=11736) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 42 tasks of which:
# * 42 complete ones were encountered:
#     - 42 ResultAggregationDistance(...)
#
# Did not run any tasks
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
# Enumerating up to 42 pipelines...
# ✓ Found 42 valid pipelines
#
# Pipeline 1:
# Task ResultAggregationDistance(config_index=, routing_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.routing.midpoint", "task_class": "Midpoint", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"pick_list_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.clark_and_wright_nn", "task_class": "ClarkAndWrightNN", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]}}]})
# Requires {'routing_plan': Midpoint(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, pick_list_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.clark_and_wright_nn", "task_class": "ClarkAndWrightNN", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]})}
# Task Midpoint(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, pick_list_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.clark_and_wright_nn", "task_class": "ClarkAndWrightNN", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]})
# Requires {'instance': InstanceLoader(config_index=), 'pick_list_plan': ClarkAndWrightNN(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, order_selection_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]})}
# Task InstanceLoader(config_index=)
# Requires []
# Task ClarkAndWrightNN(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, order_selection_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]})
# Requires {'instance': InstanceLoader(config_index=), 'order_selection_plan': DummyOS(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, item_assignment_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]})}
# Task InstanceLoader(config_index=)
# Requires []
# Task DummyOS(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, item_assignment_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]})
# Requires {'instance': InstanceLoader(config_index=), 'item_assignment_plan': GreedyIA(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []})}
# Task InstanceLoader(config_index=)
# Requires []
# Task GreedyIA(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []})
# Requires {'instance': InstanceLoader(config_index=)}
# Task InstanceLoader(config_index=)
# Requires []
#
# └─--[ResultAggregationDistance]
#     └─--[Midpoint]
#         |---[InstanceLoader]
#         └─--[ClarkAndWrightNN]
#             |---[InstanceLoader]
#             └─--[DummyOS]
#                 |---[InstanceLoader]
#                 └─--[GreedyIA]
#                     └─--[InstanceLoader]
#
# Pipeline 2:
# Task ResultAggregationDistance(config_index=, routing_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.routing.midpoint", "task_class": "Midpoint", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"pick_list_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.seed", "task_class": "ClosestDepotMinDistanceSeedBatching", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]}}]})
# Requires {'routing_plan': Midpoint(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, pick_list_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.seed", "task_class": "ClosestDepotMinDistanceSeedBatching", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]})}
# Task Midpoint(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, pick_list_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.seed", "task_class": "ClosestDepotMinDistanceSeedBatching", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]})
# Requires {'instance': InstanceLoader(config_index=), 'pick_list_plan': ClosestDepotMinDistanceSeedBatching(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, order_selection_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]})}
# Task InstanceLoader(config_index=)
# Requires []
# Task ClosestDepotMinDistanceSeedBatching(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, order_selection_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]})
# Requires {'instance': InstanceLoader(config_index=), 'order_selection_plan': DummyOS(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, item_assignment_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]})}
# Task InstanceLoader(config_index=)
# Requires []
# Task DummyOS(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, item_assignment_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]})
# Requires {'instance': InstanceLoader(config_index=), 'item_assignment_plan': GreedyIA(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []})}
# Task InstanceLoader(config_index=)
# Requires []
# Task GreedyIA(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []})
# Requires {'instance': InstanceLoader(config_index=)}
# Task InstanceLoader(config_index=)
# Requires []
#
# └─--[ResultAggregationDistance]
#     └─--[Midpoint]
#         |---[InstanceLoader]
#         └─--[ClosestDepotMinDistanceSeedBatching]
#             |---[InstanceLoader]
#             └─--[DummyOS]
#                 |---[InstanceLoader]
#                 └─--[GreedyIA]
#                     └─--[InstanceLoader]
#
# Pipeline 3:
# Task ResultAggregationDistance(config_index=, routing_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.routing.midpoint", "task_class": "Midpoint", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"pick_list_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.seed_shared_articles", "task_class": "ClosestDepotMaxSharedArticlesSeedBatching", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]}}]})
# Requires {'routing_plan': Midpoint(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, pick_list_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.seed_shared_articles", "task_class": "ClosestDepotMaxSharedArticlesSeedBatching", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]})}
# Task Midpoint(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, pick_list_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.batching.seed_shared_articles", "task_class": "ClosestDepotMaxSharedArticlesSeedBatching", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"order_selection_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]}}]})
# Requires {'instance': InstanceLoader(config_index=), 'pick_list_plan': ClosestDepotMaxSharedArticlesSeedBatching(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, order_selection_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]})}
# Task InstanceLoader(config_index=)
# Requires []
# Task ClosestDepotMaxSharedArticlesSeedBatching(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, order_selection_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.order_selection.dummy_order_selection", "task_class": "DummyOS", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}, {"item_assignment_plan": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]}}]})
# Requires {'instance': InstanceLoader(config_index=), 'order_selection_plan': DummyOS(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, item_assignment_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]})}
# Task InstanceLoader(config_index=)
# Requires []
# Task DummyOS(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}, item_assignment_plan={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.components.item_assignment.greedy_item_assignment", "task_class": "GreedyIA", "arguments": [{"instance": {"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []}}]})
# Requires {'instance': InstanceLoader(config_index=), 'item_assignment_plan': GreedyIA(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []})}
# Task InstanceLoader(config_index=)
# Requires []
# Task GreedyIA(config_index=, instance={"__type__": "cls_luigi.inhabitation_task.RepoMeta.WrappedTask", "module": "ware_ops_pipes.pipelines.templates.template_1", "task_class": "InstanceLoader", "arguments": []})
# Requires {'instance': InstanceLoader(config_index=)}
# Task InstanceLoader(config_index=)
# Requires []
#
# └─--[ResultAggregationDistance]
#     └─--[Midpoint]
#         |---[InstanceLoader]
#         └─--[ClosestDepotMaxSharedArticlesSeedBatching]
#             |---[InstanceLoader]
#             └─--[DummyOS]
#                 |---[InstanceLoader]
#                 └─--[GreedyIA]
#                     └─--[InstanceLoader]
#
# ✓ Running 42 pipelines...
#
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_005a39dc8f_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_006a523e91_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_017dbd2eee_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_044b0b57b8_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_08d14f6bd6_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_0c4ba1a348_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_0f583a89a7_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_0fd8485f88_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_1591452464_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_17776b3738_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_23447219e7_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_23b5aac176_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_2d642ffb8e_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_3b0c14720d_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_49ea68daa9_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_57149dcb38_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_5c2ec5417c_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_609f55067a_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_62188dd01f_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_64f04937b6_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_65374d1ee6_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_6ecede1a1e_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_733e984cbe_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_75ef682193_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_88fa9b4627_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_937117920e_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_96e6963a87_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_9d02b6da68_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_9f4afdb7ff_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_ae5c5fc26a_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_af121e28f4_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_afef3e2157_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_b77516d9d1_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_c007d92264_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_c394e48f1b_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_cd446e708e_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_d4ff750664_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_e8a017f9d4_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_e9bf960bc7_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_ee16996b43_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_f4c36c9bbe_summary.json
# file C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ResultAggregationDistance______type______cl_f7963d6441_summary.json
#
# Top 5 pipelines for instances_d5_ord5_MAL.txt:
#  rank                                                                                                     pipeline_id  value  gap_pct
#     1 GreedyItemAssignment+NearestNeighbourhoodRouting_RandomBatching_LocalSearchBatching+NearestNeighbourhoodRouting 383.09      0.0
#     2                    GreedyItemAssignment+NearestNeighbourhoodRouting_SavingsBatching+NearestNeighbourhoodRouting 383.09      0.0
#     3                  GreedyItemAssignment+closest_to_depot_shared_articles_SeedBatching+NearestNeighbourhoodRouting 383.09      0.0
#     4                                  GreedyItemAssignment+SShapeRouting_SavingsBatching+NearestNeighbourhoodRouting 383.09      0.0
#     5                                                 GreedyItemAssignment+RandomBatching+NearestNeighbourhoodRouting 383.09      0.0
#
# Saved: C:\Users\zm0714\Documents\Projekte\ware_ops_pipes\experiments\output\FoodmartData\instances_d5_ord5_MAL.txt\ranking_tours_summary_total_distance.csv
#
# Best: GreedyItemAssignment+NearestNeighbourhoodRouting_RandomBatching_LocalSearchBatching+NearestNeighbourhoodRouting = 383.09

# %% [markdown]
# As the ranker shows, the best pipeline is the combination of GreedyItemAssignment, Local Search Batching with a RandomBatching component for constructing the initial solution and NearestNeighbourhoodRouting as the routing component
